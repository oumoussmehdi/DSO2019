# %% [markdown]
# # Python Tutorial - DSO 2019 Training
#
# This tutorial is intended to guide people wishing to use Python to participate in the challenge.
#
# It has 5 steps:
#
# 1. Importing data
# 2. Descriptive analysis
# 3. Data Preparation
# 4. Creating a template
# 5. Calculation of predictions and submissions
#
# # Data Import
#
# Let's install the necessary packages for this tutorial:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
pd.set_option('display.max_columns', 500)

# %%
# %%time
X_train = pd.read_csv("data/X_train.csv", index_col=0, error_bad_lines=False)
X_test = pd.read_csv("data/X_test.csv", index_col=0, error_bad_lines=False)
y_train = pd.read_csv("data/y_train.csv", index_col=0)
# Out:
# b'Skipping line 2168: expected 31 fields, saw 33\nSkipping line 4822: expected 31 fields, saw 37\nSkipping line 4859: expected 31 fields, saw 37\nSkipping line 7342: expected 31 fields, saw 37\n'
# Wall time: 425 ms

# %%
print("Dimension X_train:", X_train.shape)
print("Dimension X_test:", X_test.shape)
# Out:
# Dimension X_train: (8880, 30)
# Dimension X_test: (2960, 30)

# %%
X_train.head(3)
# Out:
#     images_count  image_width  image_height  \
# id
# 0              3       3458.0        2552.0
# 1              2       2486.0        2254.0
# 2              3       1536.0        1536.0
#
#                                             image_url  \
# id
# 0   https://d1kvfoyrif6wzg.cloudfront.net/assets/i...
# 1   https://d1kvfoyrif6wzg.cloudfront.net/assets/i...
# 2   https://d1kvfoyrif6wzg.cloudfront.net/assets/i...
#
#                                   product_description product_size  \
# id
# 0   Superbe petit top bustier avec explosion de co...           44
# 1         Radio ITT Océnic Flirt, année 70\nPour déco          NaN
# 2   Veste boléro à manches courtes NÛMPH. Gris chi...           40
#
#                    material  age warranty  year        color  product_width  \
# id
# 0          100 % polyester   NaN      NaN   NaN  Multicolore            NaN
# 1                 Plastique  NaN      NaN   NaN        Jaune            NaN
# 2   Polyester, coton, laine  NaN      NaN   NaN         Gris            NaN
#
#    wifi  condition  product_length  shoe_size vintage        brand author  \
# id
# 0   NaN   bon état             NaN        NaN   False          NaN    NaN
# 1   NaN  en l'état             NaN        NaN    True  ITT Océanic    NaN
# 2   NaN       neuf             NaN        NaN   False        Nûmph    NaN
#
#    editor  product_height  weight  price         category  \
# id
# 0     NaN             NaN   200.0    4.5             mode
# 1     NaN             NaN  1000.0   15.0  mobilier - deco
# 2     NaN             NaN   360.0   16.0  label selection
#
#                       sub_category_1 sub_category_2 sub_category_3  \
# id
# 0   tops, t-shirts, débardeurs femme            NaN            NaN
# 1            bibelots et objets déco            NaN            NaN
# 2                               mode     mode femme            NaN
#
#    sub_category_4              product_name  \
# id
# 0             NaN  Top bustier multicolore
# 1             NaN         Radio ITT Océanic
# 2             NaN                       NaN
#
#                                        store_name
# id
# 0                           Emmaüs 88 Neufchateau
# 1   Communauté Emmaüs Thouars (magasin Parthenay)
# 2                           Label Emmaüs Chambéry

# %% [markdown]
# # Descriptive analysis
#
# ## Structure of the datasets
#
# The train dataset contains the characteristics and time of sale of **8880** items sold on the Emmaus website. It is this dataset that we will use to create a model. Each object is described by an observation of X variables. These variables are described in the ```description.pdf``` file in the USB key.
#
# The test dataset contains the characteristics of **2960 objects**, which must be predicted for the time of sale. Unlike the train, the sell time is of course not filled in and an ```id``` column has been added to identify the predictions during the submission stage.

# %%
X_train.describe(include='all').T
# Out:
#                     count unique  \
# images_count         8880    NaN
# image_width          8823    NaN
# image_height         8823    NaN
# image_url            8823   8775
# product_description  8880   8836
# product_size         2414     33
# material             3947   1722
# age                   120     18
# warranty              101      2
# year                 1497    NaN
# color                5321     18
# product_width         107    NaN
# wifi                   83      2
# condition            8856      5
# product_length         90    NaN
# shoe_size             223    NaN
# vintage              5890      2
# brand                4329   2658
# author               1412   1021
# editor               1437    655
# product_height        113    NaN
# weight               8878    NaN
# price                8880    NaN
# category             8879     11
# sub_category_1       7292    169
# sub_category_2       3620    145
# sub_category_3        927    124
# sub_category_4         70     37
# product_name         8064   7921
# store_name           8880     46
#
#                                                                    top  freq  \
# images_count                                                       NaN   NaN
# image_width                                                        NaN   NaN
# image_height                                                       NaN   NaN
# image_url            https://d1kvfoyrif6wzg.cloudfront.net/assets/i...     4
# product_description                 Relié, 48 pages, couverture usagée     6
# product_size                                                        38   402
# material                                                         Coton   144
# age                                                                 4a    14
# warranty                                                        6 mois   100
# year                                                               NaN   NaN
# color                                                      Multicolore  1063
# product_width                                                      NaN   NaN
# wifi                                                              True    62
# condition                                                     bon état  4537
# product_length                                                     NaN   NaN
# shoe_size                                                          NaN   NaN
# vintage                                                          False  3832
# brand                                                              tmp    93
# author                                                           Hergé    21
# editor                                                          Pocket    80
# product_height                                                     NaN   NaN
# weight                                                             NaN   NaN
# price                                                              NaN   NaN
# category                                                          mode  2982
# sub_category_1                                                    mode   511
# sub_category_2                                         label selection  1132
# sub_category_3                         les coups de coeur des vendeurs    65
# sub_category_4                         les coups de coeur des vendeurs     7
# product_name                                             carte postale     6
# store_name                                                 Emmaüs Lyon   895
#
#                         mean      std  min     25%   50%   75%          max
# images_count         3.63345  2.04857    0       2     3     5           29
# image_width          1807.82  1025.25   58    1000  1536  2448         5472
# image_height         1801.77  1101.21   64   970.5  1536  2448         5472
# image_url                NaN      NaN  NaN     NaN   NaN   NaN          NaN
# product_description      NaN      NaN  NaN     NaN   NaN   NaN          NaN
# product_size             NaN      NaN  NaN     NaN   NaN   NaN          NaN
# material                 NaN      NaN  NaN     NaN   NaN   NaN          NaN
# age                      NaN      NaN  NaN     NaN   NaN   NaN          NaN
# warranty                 NaN      NaN  NaN     NaN   NaN   NaN          NaN
# year                 14810.1   496237    0    1979  1998  2007  1.92019e+07
# color                    NaN      NaN  NaN     NaN   NaN   NaN          NaN
# product_width        42.0589  20.5453   10      30    40  46.5          140
# wifi                     NaN      NaN  NaN     NaN   NaN   NaN          NaN
# condition                NaN      NaN  NaN     NaN   NaN   NaN          NaN
# product_length          65.2  36.2889   24  35.125    50    80          160
# shoe_size             39.139  2.63781   25      37    39    41           48
# vintage                  NaN      NaN  NaN     NaN   NaN   NaN          NaN
# brand                    NaN      NaN  NaN     NaN   NaN   NaN          NaN
# author                   NaN      NaN  NaN     NaN   NaN   NaN          NaN
# editor                   NaN      NaN  NaN     NaN   NaN   NaN          NaN
# product_height       64.2788  33.4202    9    45.5    61    72          198
# weight               7794.86  82201.3  0.1     252   500  1000      2.2e+06
# price                21.5033  44.0243  0.5       6    10    20         2200
# category                 NaN      NaN  NaN     NaN   NaN   NaN          NaN
# sub_category_1           NaN      NaN  NaN     NaN   NaN   NaN          NaN
# sub_category_2           NaN      NaN  NaN     NaN   NaN   NaN          NaN
# sub_category_3           NaN      NaN  NaN     NaN   NaN   NaN          NaN
# sub_category_4           NaN      NaN  NaN     NaN   NaN   NaN          NaN
# product_name             NaN      NaN  NaN     NaN   NaN   NaN          NaN
# store_name               NaN      NaN  NaN     NaN   NaN   NaN          NaN

# %%
y_train.duration.value_counts()
# Out:
# 0    3027
# 2    2953
# 1    2900
# Name: duration, dtype: int64

# %% [markdown]
# The dataset is very balanced, each of the 3 classes has a frequency close to 1/3.

# %% [markdown]
# # Model Creation
#
# Now is the time to create a model. In this tutorial we will build a Random Forest.
#
# To do this we use the variables ```["weight","price","nb_images","image_length","image_width","category"]```.
#
# To avoid overfitting and estimate the true performance of our model we will use the criterion of cross-validation **k-fold** method (cross-validation).

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import Imputer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_predict
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ### Imputation of missing values by the value "missing"

# %%
X_train.category.fillna('missing', inplace=True)
X_test.category.fillna('missing', inplace=True)

# %% [markdown]
# ### Encoding categorical features
#
# Machine learning algorithms expect to have **numbers** as input, not strings. That's why we turn **categorical features** into numbers, using ```LabelEncoder ()```

# %%
X_train.category.unique()
# Out:
# array(['mode', 'mobilier - deco', 'label selection', 'multimédia',
#        'loisirs', 'enfance', 'librairie', 'culture - loisirs',
#        'les coups de coeur des vendeurs', 'mobilier - deco - maison',
#        'créations', 'missing'], dtype=object)

# %%
le = LabelEncoder()
X_train['category'] = le.fit_transform(X_train.category)
X_test['category'] = le.transform(X_test.category)

# %%
features = ["weight", "price", "images_count",
            "image_width", "image_height", "category"]

ppl = Pipeline([("imputer", Imputer(strategy='median')),
                ("clf", RandomForestClassifier(n_estimators=10))])

ppl.fit(X_train.loc[:, features], np.ravel(y_train))

pred_train = ppl.predict_proba(X_train.loc[:, features])
pred_cv = cross_val_predict(ppl, X_train.loc[:, features], np.ravel(y_train),
                            method='predict_proba', cv=5, n_jobs=-1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %% [markdown]
# # Calcul de l'erreur: logloss

# %%
from sklearn.metrics import log_loss

# %%
print("LogLoss on train sample:",log_loss(y_pred=pred_train, y_true=y_train))
print("LogLoss on train sample (CV):",log_loss(y_pred=pred_cv, y_true=y_train))
# Out:
# LogLoss on train sample: 0.29625210734455876
# LogLoss on train sample (CV): 3.1504084002015773

# %% [markdown]
# # Calcul des predictions

# %%
pred_test = ppl.predict_proba(X_test.loc[:, features])

# %%
df_submission = pd.DataFrame(pred_test, index=X_test.index)

# %% [markdown]
# # Submission
#
# ## Possibility #1: via the QScore API
#
# 1. Go to the platform [QScore](https://qscore.datascience-olympics.com) then in "Submissions"> "Submit from your Python Notebook"
# 2. Get your TOKEN
# 3. Replace it in the function below and execute it

# %%
import io, math, requests

# Only works in Python3, see comment below for Python2
def submit_prediction(df, sep=',', **kwargs):
    # TOKEN to recover on the platform: "Submissions"> "Submit from your Python Notebook"
    TOKEN='ad30dbf801679bec096e2e1cb2c22196ac4f8ee4aabd83b0e820aa033ec347ac1db1f474bf754dfddf627c7d7ee78a62389bf48e19584f28bfea2a92aeb104c2'  
    URL='https://qscore.datascience-olympics.com/api/submissions'
    #buffer = io.BytesIO() # Python 2
    buffer = io.StringIO() # Python 3
    df.to_csv(buffer, sep=sep, **kwargs)
    buffer.seek(0)
    r = requests.post(URL, headers={'Authorization': 'Bearer {}'.format(TOKEN)},files={'datafile': buffer})
    if r.status_code == 429:
        raise Exception('Submissions are too close. Next submission is only allowed in {} seconds.'.format(int(math.ceil(int(r.headers['x-rate-limit-remaining']) / 1000.0))))
    if r.status_code != 200:
        raise Exception(r.text)

# %%
submit_prediction(df_submission, sep=',', index=True)

# %% [markdown]
# ## Possibility #2: Submit a CSV file
#
# 1. Go to the platform [QScore](https://qscore.datascience-olympics.com) then in "Submissions"> "Submit with a file"
# 2. Deposit the CSV file

# %%
df_submission.to_csv("my_prediction.csv", index_label="id", header=['0', '1', '2'])
